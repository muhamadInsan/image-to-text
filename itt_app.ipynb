# %%
import pandas as pd
import numpy as np
import camelot

# %%
# import the following libraries
# will convert the image to text string
import pytesseract      
  
# adds image processing capabilities
from PIL import Image    

 # opening an image from the source path
img = Image.open('dua.png')
# img.save('ktp4v3.jpeg', quality=100)
# imgGray = img.convert('L')
# imgGray.save('test_gray.jpg')  

pytesseract.pytesseract.tesseract_cmd ='C:/Program Files/Tesseract-OCR/tesseract.exe' 
# pytesseract.pytesseract.
# converts the image to result and saves it into result variable
result = pytesseract.image_to_string(img)

text = pd.DataFrame(result.splitlines()) 
print(result)
# Out:
# Memonitor perubahan serviks, penurunan bagian terendah setiap 4 jam
# pada fase laten dan 2-4 jam pada fase aktif ~
#
# Memonitor pengeluaran urine setiap 2 jam seluruh hasil pemantauan
# dicatat dalam partograf
#
# Menghadirkan orang yang dianggap penting bagi ibu seperti suami,
# keluarga atau teman terdekat
#
# Menginformasikan hasil pemeriksaan dan rencana asuhan niga ca
# serta kemajuan persalinan kepada ibu dan keluarganya ;
#
# Mengatur aktivitas, posisi dan membimbing ibu untuk jeaalet
# sewaktu ada his
#
# Menjaga privasi ibu
#
# Menjaga kebersihan diri ibu .
#
# Mengatasi ketidaknyamanan ibu serta rasa seperti rasa panas, rasa nyeri
# ketika his misalnya dengan membuat rasa'sejuk, masase
#
# Memberikan cukup minum dan makan
#
# Mempertahankan kekosongan kandung kemih
#
# Mempertahankan rasa kedekatan misalnya dengan sentuhan dan
# memberikan dukungan terus menerus

# %%
text
# Out:
#                                                     0
# 0   Memonitor perubahan serviks, penurunan bagian ...
# 1       pada fase laten dan 2-4 jam pada fase aktif ~
# 2
# 3   Memonitor pengeluaran urine setiap 2 jam selur...
# 4                             dicatat dalam partograf
# 5
# 6   Menghadirkan orang yang dianggap penting bagi ...
# 7                        keluarga atau teman terdekat
# 8
# 9   Menginformasikan hasil pemeriksaan dan rencana...
# 10  serta kemajuan persalinan kepada ibu dan kelua...
# 11
# 12  Mengatur aktivitas, posisi dan membimbing ibu ...
# 13                                    sewaktu ada his
# 14
# 15                                Menjaga privasi ibu
# 16
# 17                      Menjaga kebersihan diri ibu .
# 18
# 19  Mengatasi ketidaknyamanan ibu serta rasa seper...
# 20  ketika his misalnya dengan membuat rasa'sejuk,...
# 21
# 22                   Memberikan cukup minum dan makan
# 23
# 24            Mempertahankan kekosongan kandung kemih
# 25
# 26  Mempertahankan rasa kedekatan misalnya dengan ...
# 27                  memberikan dukungan terus menerus
